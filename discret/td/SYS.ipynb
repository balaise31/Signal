# %% [markdown]
# ---
# # SYS TD systèmes discrets
# ---
#
# Apprendre à passer entre les différentes représentations :
#    - schema blocks
#    - équation aux différences : récurrence
#    - fonction de transfert en Z
#    - réponse harmonique
#    - réponse impulsionnelle
#    - représentation d'état
#
# Des liens "aux bons moments" dans les vidéos suivantes sont utilisés **au fil dus sujet**:
#   - [Vidéo MA1](https://youtu.be/QRiAfbWLMw8)
#   - [Vidéo MA2](https://youtu.be/sKBlBBVbRWw)
#   - [Vidéo ARMA](https://youtu.be/TjNE5sKsKRM)
#   - [Vidéo G(z) -> RIp](https://youtu.be/_Mrx9QQ-z5o)
#   - [G(z) -> G(f) : Filtrage](https://youtu.be/vaGALhd2ohM)

# %% [markdown]
# ---
# ## II - MA
# ---
#
#
# **Systèmes Mooving Average (MA)** à moyenne glissante.
#
#
# <img src='../poly/tikz/ma_ab.png' width="400" height="400" style="background-color: orange">
#
# Les cercles sont des multiplieurs, l'opérateur T est le retard unitaire, le cercle avec un + est un additionneur.
#
# ###  Q1
# Identifiez les trois types d'opérateurs utilisés et dites pour chacun si ce sont des systèmes LTI (Linéaire à Temps Invariant), des systèmes causaux.
# Conclure si le système entier est lui-même LTI, causal.
#
#
# ###  Q2 (Optionnel)
# [Vidéo MA2 : RIp et Causalité](https://youtu.be/sKBlBBVbRWw)
#
# Donnez la réponse impulsionnelle $h$ du système et tracez son graphique. On remplacera l'entrée $x$ par l'impulsion $\delta_0$ dans le schéma et propagera le signal dans le schéma block jusqu'à la sortie.
#
#
# ##  Q3
# [Vidéo MA1 : Block -> récurrence](https://youtu.be/QRiAfbWLMw8?t=0)
#
#
# Passez du schéma block à l'équation aux différences (récurrence) que vous mettrez sous forme :
#   - $y[k+1]=\ldots$
#   - $y[k]=\ldots$
#
# Simplifiez les expressions et dites de quel ordre est ce système.
# Le système est-il auto-regressif ? récurrent ? à moyenne glissante (mooving average) ? bouclé ?
#
# ###  Q4
# [Vidéo MA1 : Récurrence -> G(z)](https://youtu.be/QRiAfbWLMw8?t=479)
#
# En se rappelant que $z^{-1}$ est le système/signal associé à l'opérateur retard $T$, donnez la fonction de transfert en Z en partant de chaque récurrence :
#  - $y[k+1]=\ldots \implies G(z) = \frac{Y(z)}{X(z)} = \ldots$
#  - $y[k]=\ldots \implies G(z) = \frac{Y(z)}{X(z)} = \ldots$
#
# Retrouvez la fonction de transfert en réécrivant le schéma block avec des transformées en Z (en continu on remplacerait un block dérivateur par un block $p$)et en le simplifiant en un seul block.
#
# ###  Q5
# [Vidéo MA2 : Transformée inverse de H(z)](https://youtu.be/sKBlBBVbRWw?t=252)
#
# Remplacez $X(z)$ par la transformée en Z de $\delta_0$ dans la relation $G(z) = \frac{Y(z)}{X(z)}$ et trouvez ainsi la transformée de la réponse impulsionnelle $H(z)$.
#
# Retrouvez la réponse impulsionnelle $h$ de la question Q2 en faisant, cette fois-ci, la transofrmée inverse de $H(z)$ (il n'y a pas de véritable calcul à faire).
#
# À partir de la réponse impulsionnelle concluez si le système est-il FIR (Finite Impluse Response) ou  IIR (Infinite Impulse response) ?
#
# ###  Q6
# [Vidéo MA2 : RIp et Causalité](https://youtu.be/sKBlBBVbRWw)
#
# Retrouvez la propriété de causalité de la Q1 mais à partir de la RIp $h$.
#
#
# ###  Q7
# [Vidéo MA2 : RIp h -> stabilité](https://youtu.be/sKBlBBVbRWw?t=302)
#
# Quelle propriétée doit vérifier la RIp pour que le système soit stable ? Est-ce une condition nécessaire et suffisante ? Concluez si ce système est BIBO stable à partir de sa RIp.
#
# BONUS : démontrez que $\Sigma h$ ACV $\implies$ H stable
#
# ###  Q8
# [Vidéo MA2 : Block forme directe I](https://youtu.be/sKBlBBVbRWw?t=523)
#
# Donnez un schéma block en transformée en Z sous forme Directe I (chaîne de retards puis combinaison linéaire). Retrouvez de quel ordre est ce système.
#
# ###  Q9
# On appelle BIBO la propriété de stabilité : "Bounded Input Bounded Output"
#
# A-t-on :
#  - $MA \implies FIR$ ?
#  - $FIR \implies BIBO$ ? Ou $BIBO \implies FIR$ ? Ou $BIBO \iff FIR$ ?
#  - $MA \implies FIR \implies BIBO$ ?
#  - $BIBO \iff FIR \implies MA$ ?

# %% [markdown]
# ---
# ## IV - AR
# ---
#
# **Système Auto-Régressif (AR)**
#
#
# <img src='../poly/tikz/ar_o1.png' width="400" height="400" style="background-color: orange">
#
#
# Nous voulons créer un système capable de générer en réponse impulsionnelle une exponentielle causale (comme un premier ordre en continu)
#
# $$h(t) = e^{-t/\tau}.u(t)$$
#
# ### Q1
# Discrétisez le signal $t\mapsto h(t)$ et montrez qu'il s'agit d'une suite géométrique $h[k]=a^k.u[k]$ où vous exprimerez $a$ en fonction de $\tau$ et $T_e$.
#
# ### Q2
# Représentez $h$ graphiquement pour $a=\frac{1}{2}$ puis $1$ puis $2$.
#
# Déduisez une condition nécessaire et suffisante de stabilité BIBO du système H avec $a$ puis avec $\tau$ (Il y a une CNS de CVA des séries géométriques à utiliser) :
#  - H BIBO stable $\iff \quad |a| \ldots $
#  - H BIBO stable $\iff \quad \tau \ldots$
#
# On vérifie que la condition sur $\tau$ correspond aux conditions de stabilité en continu (trouvez $G(p)$, le(s) pole(s), etc.)
#
# ### Q3
#
# [Vidéo AR1 : Récurrence](https://youtu.be/TjNE5sKsKRM?t=19)
#
#
# Traduire le schéma block en récurrence et calculer la réponse impulsionnelle $h$.
# On doit obtenir le signal de la question Q1.
#
# Conclure sur la stabilité d'un système du premier ordre à pôle simple $a\in\mathbb{R}$.
#
# > **Remarque**
# >
# > On considère un **système à mémoire nulle** ($y[k]=0, \forall k<0$) mais **avec entrée non nulle** $\vec{x}=\vec{\delta_0}$ pour établir la  **condition initiale (CI)** $y[0]=1$ :
# > $y[k]=a.y[k-1] + x[k] \quad \forall k\in\mathbb{Z}$ avec C.I. nulles $y[k]=0,\quad \forall k<0$.
# >
# > De manière équivalente
# >
# > Un **un système à mémoire $y[0]=1,\; y[k<0]=0$** mais avec **une entrée nulle** (le système sans entrée $x$ est dit autonome) permet d'établir la **même condition initiale** :
# > $y[k]=a.y[k-1] \quad \forall k>0$ avec condition initiale $y[0]=1$

# %% [markdown]
# ### Q4
# Donnez la fonction de transfert $G(z)$ de ce système à partir de la récurrence et vérifiez bien que $H(z) = G(z).\underbrace{1}_{Z\{\delta_0\}}$.
#
# Pour cela, donnez $H(z)$ en appliquant la formule directe de transformée en Z qui se retrouve simplement avec la décomposition de $h$ dans le temps :
#   - soit $\vec{h[k]} = \sum\limits_{j=0}^{\infty} h[j] . \vec{\delta_j[k]}  \quad\implies\quad H(z) = Z\{\vec{h}\}(z) =  \sum\limits_{j=0}^{\infty} h[j] . Z\{\vec{\delta_j[k]}\} = \ldots$
#   - Utilisez la formule de la somme d'une série géométrique pour retrouver G(z)
#
#   - Exprimez G(z) comme une fraction rationnelle en $z^{-1}$ et faites une division par les puissances croissante de $z^{-1}$ pour retrouver $H(z)$...
#
# > Apprenez à faire une division par les puissances croissantes [Vidéo G(z) -> RIp](https://youtu.be/_Mrx9QQ-z5o?t=1366) et
#
# ### Q5
# Ce système est-il MA (moyenne pondérée glissante) ? AR (autorégressif) ? Récursif ? Bouclé ?
#
# ### Q6
# Déterminez l'ordre, les pôles et les zéros de $G(z)$. **Attention ! il faut exprimer en fonction de $z$ et non $z^{-1}$**
#
# Quelle est la condition de stabilité en discret en fonction des zéros et des pôles ?
#
# ### Q7
#
# Donnez un schéma block en transformée en Z sous forme Directe I (chaîne de retards et combinaison linéaire).
#
# Retrouvez de quel ordre est ce système.
#
# ### Q8
# On appelle BIBO la propriété de stabilité : "Bounded Input Bounded Output"
#
# A-t-on :
#  - $IIR \implies AR$ ?
#  - $IIR \implies \overline{BIBO}$ ? Ou bien $ \overline{BIBO} \implies IIR$ ? Ou bien $\overline{BIBO} \iff IIR$ ?
#  - $AR \iff IIR \implies \overline{BIBO}$ ?
#  - $\overline{BIBO} \implies IIR \implies AR$ ?

# %% [markdown]
# ---
# ## I - ARMA
# ---
#
# **Système Auto Regressive Mooving Average (ARMA)** Auto-Régressif à moyenne glissante
#
# <img src='../poly/tikz/arma_o1.png' width="400" height="400" style="background-color: orange">
#
# ### Q1 - Manipulation de schéma bloc
# Repérez le(s) bouclages(s) (AR) et les moyennes glissantes (MA) et décomposez le schéma bloc en séparant clairement MA puis AR.
#
# $\vec{x} \overset{MA}{\longrightarrow} \vec{w} \overset{AR}{\longrightarrow} \vec{y}$
#
# ### Q2 - Bloc -> Fonction de transfert
#
# On note l'opérateur retard $q=z^{-1}$. Donnez, en les exprimant d'abord avec des retards $q$ puis avec des avances $z$, les fonctions de transfert
#  - $MA(z)=\frac{W(z)}{X(z)}$,
#  - $AR(z)=\frac{Y(z)}{W(z)}$,
#  - la fonction de transfert totale $G(z)=\frac{Y(z)}{X(z)}$.
#
# ### Q4 - Stabilité - Pôles et zéros
# Identifiez les pôles et les zéros du système et concluez sur la stabilité.
#
# ### Q3 - F. Transfert -> Equation aux Différences
# Donnez, à partir de $G(1/q)$, la récurrence  du système sous forme $y[k+1]= \ldots y[k] + \ldots x[\ldots] \ldots x[\ldots]$ et vérifiez qu'elle correspond au schéma bloc.
#
# ### Q5 - F.T. -> Réponse Impulsionnelle
# Trouvez la réponse impulsionnelle en décomposant $G(z)$ en $MA(z)$ (numérateur FIR) puis $AR(z)$ (dénominateur IIR) :
#   - exprimez la réponse impulsionnelle du MA sous forme de deux impulsions
#   - exprimez la réponse impulsionnelle du AR en réutilisant les résultat de l'exercice MA (1er ordre)
#   - par linéarité du système, trouvez $h$ comme la somme des réponses AR à une somme finie d'impulsions issue du MA(FIR)
#
# N'oubliez pas que les systèmes sont causaux et que **si l'on retarde un signal causal, il faut aussi retarder l'échelon de heaviside** :
# utiliser par exemple $a^{k-1}u[k-1]$ pour annuler la réponse pour $k<1$
#
# ### Q6 - Idem par division en puissances croissantes
# Vérifiez le résultat en faisant une division par les puissances croissantes de $q = z^{-1}$ de la fonction de transfert prise avec une entrée impulsionnelle.
#
# Vous vérifierez ainsi sur les quelques premiers termes que la réponse de la Q5) fonctionne.
#
# ### Q7 - RIp -> causalité et stabilité
# À partir de $h$ dites pourquoi le système est stable et causal. Vérifiez la cohérence avec la Q2.
#
# ### Q8 - Manipulation de blocs -> forme canonique trans
#
# [Vidéo ARMA: Forme Directe II](https://youtu.be/TjNE5sKsKRM?t=844)
#
# Nous avons $G(z) = MA(z).AR(z) = AR(z).MA(z)$.
# Redessinez le schéma block en séparant d'**abord le AR** puis le MA.
#
# $\vec{x} \overset{AR}{\longrightarrow} \vec{w} \overset{MA}{\longrightarrow} \vec{y}$
#
# En permuttant le multiplieur avec le retard, regroupez les deux blocs mémoires pour n'en faire qu'un, dont l'entrée sera $w[k+1]$ et la sortie $w[k]$.
#
# Vous obtenez ainsi la **forme Directe II** canonique (et optimale en termes de mémoire).
#
# ### Q9 - F.T. -> Réponse harmonique (Bode)
#
# Donnez la réponse harmonique de ce système. Pour cela passez de $AR(z)=AR(\frac{1}{q})$ à une représentation en fréquence $AR(i\omega)$, puis pour $MA(z)$ et enfin pour $G(z)$.
#
# Dans chaque  expressions faites apparaître uniquement des termes en $e^{i\,2\pi\,\tilde{f}}$ où on note $\tilde{\omega}=\frac{\omega}{\omega_e}=\tilde{f}=\frac{f}{Fe}$ la fréquence nomalisée.
#
# Dans chaque expression vérifiez:
#   - que la réponse hamonique en $f$ est $f_e$ périodique (et donc 1 périodique en $\tilde{f}$)
#   - que la réponse est celle d'un système réel, i.e., spectre de Hilbert : $G(-\tilde{f})=\overline{G(\tilde{f})}$
#
# > AStuce de **l'arc moitiée** :
# > Simplifiez bien les paires d'exponentielles ! C'est **très fréquent en discret**:
# > $1 + e^{i.b} = e^{-i.b/2} (e^{i.b/2} + e^{-i.b/2}) = e^{-i.b/2}.2.\cos(b)$ et
# > $1 - e^{i.b} = e^{-i.b/2} (e^{i.b/2} - e^{-i.b/2}) = e^{-i.b/2}.2i.\cos(b)$ et
# > $e^{i.a} + e^{i.b} = e^{i.\frac{a+b}{2}} (e^{i.\frac{a-b}{2}} + e^{-i.\frac{a-b}{2}}) = e^{i.\frac{a+b}{2}}.2.\cos\left(\frac{a-b}{2}\right)$
# > $e^{i.a} - e^{i.b} = e^{i.\frac{a+b}{2}} (e^{i.\frac{a-b}{2}} - e^{-i.\frac{a-b}{2}}) = e^{i.\frac{a+b}{2}}.2i.\sin\left(\frac{a-b}{2}\right)$
# >
# > Come le dit M. Lebotlan : "Seul un Lycéen mémoriserait ces formules.
# >  Alors qu'en maternelle ils savaient déjà factoriser par la moitié et puis faire comme Euler et puis c'est tout !"
#
# Pour faire le tracé de la réponse harmonique faites des équivalents pour avoir les asymptotes :
#   - un équivalent pour $\tilde{f} \to 0$ doit donner une constante
#   - un équivalent pour $\tilde{f} \to \infty$ est impossible car la réponse est périodique !
#   - la fréquence discrète la plus haute que l'on puisse imaginer est $\frac{F_e}{2}$ : faites donc un équivalent $\tilde{f} \to \frac{1}{2}\infty$
#
# ### Q10 (Option) - Equa. Diff. -> Espace d'état
#
# Donnez l'ordre de ce système et la récurrence sous forme de représentation d'état discrète avec pour vecteur d'état
# ${}^T\!W_k = {}^T\![w[k], \;w[k-1], \;\ldots]$ de taille adéquate :
# $$\begin{eqnarray} W_{k+1} = A . W_k + B. x[k] \\ y[k] = C . W_k +  D. x[k]\end{eqnarray}$$
